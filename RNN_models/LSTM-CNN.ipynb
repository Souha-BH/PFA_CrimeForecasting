# %% [markdown]
# # **<center><font style="color:rgb(100,109,254)">Crime DETECTION (CNN + LSTM)</font> </center>**
#
# <center>
# <!-- <img src='https://drive.google.com/uc?export=download&id=1ucdFpzyVbzTa7kPYsJ2av-gRKgd84ICA'></center> -->

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)"> Outline </font>**
#
# - **`Step 1:` Download and Visualize the Data with its Labels**
#
# - **`Step 2:` Preprocess the Dataset**
#
# - **`Step 3:` Split the Data into Train and Test Set**
#
# - **`Step 4:` Implement the ConvLSTM Approach**
#
#     - **`Step 4.1:` Construct the Model**
#
#     - **`Step 4.2:` Compile & Train the Model**
#
#     - **`Step 4.3:` Plot Model’s Loss & Accuracy Curves**
#
# - **`Step 5:` implement the LRCN Approach**
#
#     - **`Step 5.1:` Construct the Model**
#
#     - **`Step 5.2:` Compile & Train the Model**
#
#     - **`Step 5.3:` Plot Model’s Loss & Accuracy Curves**
#
# - **`Step 6:` Test the Best Performing Model on YouTube videos**
#
# Alright, so without further ado, let's get started.

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)"> Import the Libraries</font>**
#
# We will start by installing and importing the required libraries.

# %%
# Import the required libraries.
import os
import cv2
# import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# And will set `Numpy`, `Python`, and `Tensorflow` seeds to get consistent results on every execution.

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 1: Download and Visualize the Data with its Labels</font>**
#
# In the first step, we will download and visualize the data along with labels to get an idea about what we will be dealing with. We will be using the [UCF50 - Action Recognition Dataset](https://www.crcv.ucf.edu/data/UCF50.php), consisting of realistic videos taken from youtube which differentiates this data set from most of the other available action recognition data sets as they are not realistic and are staged by actors. The Dataset contains:
#
# *   **`50`** Action Categories
#
# *   **`25`** Groups of Videos per Action Category
#
# *   **`133`** Average Videos per Action Category
#
# *   **`199`** Average Number of Frames per Video
#
# *   **`320`** Average Frames Width per Video
#
# *   **`240`** Average Frames Height per Video
#
# *   **`26`** Average Frames Per Seconds per Video
#
# Let's download and extract the dataset.

# %% [markdown]
# For visualization, we will pick `20` random categories from the dataset and a random video from each selected category and will visualize the first frame of the selected videos with their associated labels written. This way we’ll be able to visualize a subset ( `20` random videos ) of the dataset.

# %%
# Create a Matplotlib figure and specify the size of the figure.
plt.figure(figsize = (14, 14))

# Get the names of all classes/categories in UCF50.
all_classes_names = os.listdir('C:\\Users\\acer\\pfa\\videos-dataset\\Anomaly-Dataset')
# Generate a list of 20 random values. The values will be between 0-50, 
# where 50 is the total number of class in the dataset. 
random_range = random.sample(range(len(all_classes_names)), 14)

# Iterating through all the generated random values.
for counter, random_index in enumerate(random_range, 1):

    # Retrieve a Class Name using the Random Index.
    selected_class_Name = all_classes_names[random_index]
    
    # Retrieve the list of all the video files present in the randomly selected Class Directory.
    video_files_names_list = os.listdir(f'C:\\Users\\acer\\pfa\\videos-dataset\\Anomaly-Dataset\\{selected_class_Name}')

    # Randomly select a video file from the list retrieved from the randomly selected Class Directory.
    selected_video_file_name = random.choice(video_files_names_list)

    # Initialize a VideoCapture object to read from the video File.
    video_reader = cv2.VideoCapture(f'C:\\Users\\acer\\pfa\\videos-dataset\\Anomaly-Dataset\\{selected_class_Name}/{selected_video_file_name}')
    
    # Read the first frame of the video file.
    _, bgr_frame = video_reader.read()

    # Release the VideoCapture object. 
    video_reader.release()

    # Convert the frame from BGR into RGB format. 
    rgb_frame = cv2.cvtColor(bgr_frame, cv2.COLOR_BGR2RGB)

    # Write the class name on the video frame.
    cv2.putText(rgb_frame, selected_class_Name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
    
    # Display the frame.
    plt.subplot(5, 4, counter);plt.imshow(rgb_frame);plt.axis('off')

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 2: Preprocess the Dataset</font>**
#
# Next, we will perform some preprocessing on the dataset. First, we will read the video files from the dataset and resize the frames of the videos to a fixed width and height, to reduce the computations and normalized the data to range `[0-1]` by dividing the pixel values with `255`, which makes convergence faster while training the network.
#
# *But first, let's initialize some constants.*

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 64, 64

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 1000

# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "C:\\Users\\acer\\pfa\\videos-dataset\\Anomaly-Dataset"

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST =['Abuse', 'Arrest', 'Arson', 'Assault', 'Burglary', 'Explosion', 'Fighting', 'NormalVideos', 'RoadAccidents', 'Robbery', 'Shooting', 'Shoplifting', 'Stealing', 'Vandalism']

# %% [markdown]
# **Note:** *The **`IMAGE_HEIGHT`**, **`IMAGE_WIDTH`** and **`SEQUENCE_LENGTH`** constants can be increased for better results, although increasing the sequence length is only effective to a certain point, and increasing the values will result in the process being more computationally expensive.*
#
# ### **<font style="color:rgb(134,19,348)">Create a Function to Extract, Resize & Normalize Frames</font>**
#
# We will create a function **`frames_extraction()`** that will create a list containing the resized and normalized frames of a video whose path is passed to it as an argument. The function will read the video file frame by frame, although not all frames are added to the list as we will only need an evenly distributed sequence length of frames.

# %%
def frames_extraction(video_path):
    '''
    This function will extract the required frames from a video after resizing and normalizing them.
    Args:
        video_path: The path of the video in the disk, whose frames are to be extracted.
    Returns:
        frames_list: A list containing the resized and normalized frames of the video.
    '''
    print(video_path)
    # Declare a list to store video frames.
    frames_list = []
    
    # Read the Video File using the VideoCapture object.
    video_reader = cv2.VideoCapture(video_path)

    # Get the total number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)

    # Iterate through the Video Frames.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Reading the frame from the video. 
        success, frame = video_reader.read() 

        # Check if Video frame is not successfully read then break the loop
        if not success:
            break

        # Resize the Frame to fixed height and width.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1
        normalized_frame = resized_frame / 255
        
        # Append the normalized frame into the frames list
        frames_list.append(normalized_frame)
    
    # Release the VideoCapture object. 
    video_reader.release()

    # Return the frames list.
    return frames_list

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Create a Function for Dataset Creation</font>**
#
# Now we will create a function **`create_dataset()`** that will iterate through all the classes specified in the **`CLASSES_LIST`** constant and will call the function  **`frame_extraction()`** on every video file of the selected classes and return the frames (**`features`**), class index ( **`labels`**), and video file path (**`video_files_paths`**).

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in files_list:
            
            # Get the complete video path.
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)

            # Extract the frames of the video file.
            frames = frames_extraction(video_file_path)

            # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
            # So ignore the vides having frames less than the SEQUENCE_LENGTH.
            if len(frames) == SEQUENCE_LENGTH:

                # Append the data to their repective lists.
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    # Return the frames, class index, and video file path.
    return features, labels, video_files_paths

# %% [markdown]
# Now we will utilize the function **`create_dataset()`** created above to extract the data of the selected classes and create the required dataset.

# %%
# Create the dataset.
features, labels, video_files_paths = create_dataset()
# Out:
# Extracting Data of Class: Abuse
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse002_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse007_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse011_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse014_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse021_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse022_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse024_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse025_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse032_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse040_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse041_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse046_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Abuse\Abuse049_x264.mp4
# Extracting Data of Class: Arrest
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest001_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest002_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest003_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest004_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest006_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest007_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest011_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest013_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest014_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest019_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest022_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest024_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest025_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest027_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest031_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest032_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest036_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest040_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest041_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arrest\Arrest042_x264.mp4
# Extracting Data of Class: Arson
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson006_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson008_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson011_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson021_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson027_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson031_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson035_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson036_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson041_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson044_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson048_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson049_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson050_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Arson\Arson051_x264.mp4
# Extracting Data of Class: Assault
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault013_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault014_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault019_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault020_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault022_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault024_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault025_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault031_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault032_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault033_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault035_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault036_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault039_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault044_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault045_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault046_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault048_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault049_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault050_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault051_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Assault\Assault052_x264.mp4
# Extracting Data of Class: Burglary
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary007_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary011_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary036_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary043_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary050_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary051_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary054_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary056_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary059_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary060_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary068_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary069_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary070_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary078_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary080_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary081_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary092_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary093_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary094_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary097_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary098_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Burglary\Burglary099_x264.mp4
# Extracting Data of Class: Explosion
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion001_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion003_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion004_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion008_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion014_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion019_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion020_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion021_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion024_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion025_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion027_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion039_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion044_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion045_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion048_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Explosion\Explosion050_x264.mp4
# Extracting Data of Class: Fighting
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting002_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting003_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting006_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting007_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting013_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting019_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting020_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting021_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting032_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting033_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting035_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting040_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting042_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting043_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting046_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Fighting\Fighting049_x264.mp4
# Extracting Data of Class: NormalVideos
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_050_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_100_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_129_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_150_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_246_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_247_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_248_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_251_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_289_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_310_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_312_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_317_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_345_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_352_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_360_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_365_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_401_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_417_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_439_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_452_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_453_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_478_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_576_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_597_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_603_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_606_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_621_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_634_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_641_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_656_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_696_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_704_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_722_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_745_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_758_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_781_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_798_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_801_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_828_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_831_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_877_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_881_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_885_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_892_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_905_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_912_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_913_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_914_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\NormalVideos\Normal_Videos_929_x264.mp4
# Extracting Data of Class: RoadAccidents
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents009_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents022_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents042_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents046_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents049_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents053_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents056_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents064_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents072_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents073_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents077_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents082_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents084_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents086_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents088_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents090_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents094_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents095_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents107_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents111_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents114_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents118_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents123_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents133_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents143_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents144_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\RoadAccidents\RoadAccidents151_x264.mp4
# Extracting Data of Class: Robbery
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery001_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery003_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery039_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery040_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery044_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery046_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery058_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery064_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery068_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery069_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery070_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery074_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery076_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery079_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery082_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery085_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery089_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery104_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery106_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery113_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery116_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery122_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery132_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery134_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery138_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery140_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery144_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Robbery\Robbery147_x264.mp4
# Extracting Data of Class: Shooting
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting001_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting002_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting003_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting004_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting007_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting008_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting012_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting013_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting021_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting023_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting027_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting034_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting039_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting040_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting041_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting044_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting051_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting053_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shooting\Shooting054_x264.mp4
# Extracting Data of Class: Shoplifting
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting005_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting006_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting010_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting013_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting017_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting018_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting019_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting022_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting024_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting025_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting026_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting027_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting031_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting032_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting033_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting037_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting038_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting039_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting045_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting048_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting049_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting050_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting053_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Shoplifting\Shoplifting054_x264.mp4
# Extracting Data of Class: Stealing
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing015_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing016_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing028_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing029_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing030_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing031_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing047_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing055_x264.mp4
# C:\Users\acer\pfa\videos-dataset\Anomaly-Dataset\Stealing\Stealing057_x264.mp4

# %% [markdown]
# Now we will convert `labels` (class indexes) into one-hot encoded vectors.

# %%
# Using Keras's to_categorical method to convert labels into one-hot-encoded vectors
one_hot_encoded_labels = to_categorical(labels)

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 3: Split the Data into Train and Test Set</font>**
#
# As of now, we have the required **`features`** (a NumPy array containing all the extracted frames of the videos) and **`one_hot_encoded_labels`** (also a Numpy array containing all class labels in one hot encoded format). So now, we will split our data to create training and testing sets. We will also shuffle the dataset before the split to avoid any bias and get splits representing the overall distribution of the data.

# %%
# Split the Data into Train ( 75% ) and Test Set ( 25% ).
features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 4: Implement the ConvLSTM Approach</font>**
#
# In this step, we will implement the first approach by using a combination of ConvLSTM cells. A ConvLSTM cell is a variant of an LSTM network that contains convolutions operations in the network. it is an LSTM with convolution embedded in the architecture, which makes it capable of identifying spatial features of the data while keeping into account the temporal relation.
#
# <center>
# <img src="https://drive.google.com/uc?export=view&id=1KHN_JFWJoJi1xQj_bRdxy2QgevGOH1qP" width= 500px>
# </center>
#
#
# For video classification, this approach effectively captures the spatial relation in the individual frames and the temporal relation across the different frames. As a result of this convolution structure, the ConvLSTM is capable of taking in 3-dimensional input `(width, height, num_of_channels)` whereas a simple LSTM only takes in 1-dimensional input hence an LSTM is incompatible for modeling Spatio-temporal data on its own.
#
# You can read the paper [**Convolutional LSTM Network: A Machine Learning Approach for Precipitation Nowcasting**](https://arxiv.org/abs/1506.04214v1) by **Xingjian Shi** (NIPS 2015), to learn more about this architecture.

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 4.1: Construct the Model</font>**
#
#
# To construct the model, we will use Keras [**`ConvLSTM2D`**](https://keras.io/api/layers/recurrent_layers/conv_lstm2d) recurrent layers. The **`ConvLSTM2D`** layer also takes in the number of filters and kernel size required for applying the convolutional operations. The output of the layers is flattened in the end and is fed to the **`Dense`** layer with softmax activation which outputs the probability of each action category.
#
# We will also use **`MaxPooling3D`** layers to reduce the dimensions of the frames and avoid unnecessary computations and **`Dropout`** layers to prevent [overfitting](https://en.wikipedia.org/wiki/Overfitting) the model on the data. The architecture is a simple one and has a small number of trainable parameters. This is because we are only dealing with a small subset of the dataset which does not require a large-scale model.

# %%
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''

    # We will use a Sequential model for model construction
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    #model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(Flatten()) 
    
    model.add(Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %% [markdown]
# Now we will utilize the function **`create_convlstm_model()`** created above, to construct the required `convlstm` model.

# %%
# Construct the required convlstm model.
convlstm_model = create_convlstm_model()

# Display the success message. 
print("Model Created Successfully!")
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv_lstm2d (ConvLSTM2D)    (None, 1000, 62, 62, 4)   1024
#
#  max_pooling3d (MaxPooling3D  (None, 1000, 31, 31, 4)  0
#  )
#
#  time_distributed (TimeDistr  (None, 1000, 31, 31, 4)  0
#  ibuted)
#
#  conv_lstm2d_1 (ConvLSTM2D)  (None, 1000, 29, 29, 8)   3488
#
#  max_pooling3d_1 (MaxPooling  (None, 1000, 15, 15, 8)  0
#  3D)
#
#  time_distributed_1 (TimeDis  (None, 1000, 15, 15, 8)  0
#  tributed)
#
#  conv_lstm2d_2 (ConvLSTM2D)  (None, 1000, 13, 13, 14)  11144
#
#  max_pooling3d_2 (MaxPooling  (None, 1000, 7, 7, 14)   0
#  3D)
#
#  time_distributed_2 (TimeDis  (None, 1000, 7, 7, 14)   0
#  tributed)
#
#  conv_lstm2d_3 (ConvLSTM2D)  (None, 1000, 5, 5, 16)    17344
#
#  max_pooling3d_3 (MaxPooling  (None, 1000, 3, 3, 16)   0
#  3D)
#
#  flatten (Flatten)           (None, 144000)            0
#
#  dense (Dense)               (None, 14)                2016014
#
# =================================================================
# Total params: 2,049,014
# Trainable params: 2,049,014
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Check Model’s Structure:</font>**
#
#
# Now we will use the **`plot_model()`** function, to check the structure of the constructed model, this is helpful while constructing a complex network and making that the network is created correctly.

# %%
# Plot the structure of the contructed model.
plot_model(convlstm_model, to_file = 'convlstm_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 4.2: Compile & Train the Model</font>**
#
# Next, we will add an early stopping callback to prevent [overfitting](https://en.wikipedia.org/wiki/Overfitting) and start the training after compiling the model.

# %%
from numpy import savetxt
savetxt('features.csv', features, delimiter=',')
savetxt('labels.csv', labels, delimiter=',')
savetxt('vidpath.csv', video_files_paths, delimiter=',')

# %%
# Create an Instance of Early Stopping Callback
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 50, mode = 'min', restore_best_weights = True)

# Compile the model and specify loss function, optimizer and metrics values to the model
convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 3, batch_size = 4,
                                                     shuffle = True, validation_split = 0.2, 
                                                     callbacks = [early_stopping_callback])

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Evaluate the Trained Model</font>**
#
# After training, we will evaluate the model on the test set.

# %%
convlstm_model_training_history.save("rnn.h5")

# %%
# Evaluate the trained model.
model_evaluation_history = convlstm_model.evaluate(features_test, labels_test)

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Save the Model</font>**
#
# Now we will save the model to avoid training it from scratch every time we need the model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)

# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'convlstm_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save your Model.
convlstm_model.save(model_file_name)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 4.3: Plot Model’s Loss & Accuracy Curves</font>**
#
#
# Now we will create a function **`plot_metric()`** to visualize the training and validation metrics. We already have separate metrics from our training and validation steps so now we just have to visualize them.

# %%
def plot_metric(model_training_history, metric_name_1, metric_name_2, plot_name):
    '''
    This function will plot the metrics passed to it in a graph.
    Args:
        model_training_history: A history object containing a record of training and validation 
                                loss values and metrics values at successive epochs
        metric_name_1:          The name of the first metric that needs to be plotted in the graph.
        metric_name_2:          The name of the second metric that needs to be plotted in the graph.
        plot_name:              The title of the graph.
    '''
    
    # Get metric values using metric names as identifiers.
    metric_value_1 = model_training_history.history[metric_name_1]
    metric_value_2 = model_training_history.history[metric_name_2]
    
    # Construct a range object which will be used as x-axis (horizontal plane) of the graph.
    epochs = range(len(metric_value_1))

    # Plot the Graph.
    plt.plot(epochs, metric_value_1, 'blue', label = metric_name_1)
    plt.plot(epochs, metric_value_2, 'red', label = metric_name_2)

    # Add title to the plot.
    plt.title(str(plot_name))

    # Add legend to the plot.
    plt.legend()

# %% [markdown]
# Now we will utilize the function **`plot_metric()`** created above, to visualize and understand the metrics.

# %%
# Visualize the training and validation loss metrices.
plot_metric(convlstm_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(convlstm_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 5: Implement the LRCN Approach</font>**
#
# In this step, we will implement the LRCN Approach by combining Convolution and LSTM layers in a single model. Another similar approach can be to use a CNN model and LSTM model trained separately. The CNN model can be used to extract spatial features from the frames in the video, and for this purpose, a pre-trained model can be used, that can be fine-tuned for the problem. And the LSTM model can then use the features extracted by CNN, to predict the action being performed in the video.
#
#
# But here, we will implement another approach known as the Long-term Recurrent Convolutional Network (LRCN), which combines CNN and LSTM layers in a single model. The Convolutional layers are used for spatial feature extraction from the frames, and the extracted spatial features are fed to LSTM layer(s) at each time-steps for temporal sequence modeling. This way the network learns spatiotemporal features directly in an end-to-end training, resulting in a robust model.
#
# <center>
# <img src='https://drive.google.com/uc?export=download&id=1I-q5yLsIoNh2chfzT7JYvra17FsXvdme'>
# </center>
#
#
# You can read the paper [Long-term Recurrent Convolutional Networks for Visual Recognition and Description](https://arxiv.org/abs/1411.4389?source=post_page---------------------------) by Jeff Donahue (CVPR 2015), to learn more about this architecture.
#
# We will also use [**`TimeDistributed`**](https://keras.io/api/layers/recurrent_layers/time_distributed/) wrapper layer, which allows applying the same layer to every frame of the video independently. So it makes a layer (around which it is wrapped) capable of taking input of shape `(no_of_frames, width, height, num_of_channels)` if originally the layer's input shape was `(width, height, num_of_channels)` which is very beneficial as it allows to input the whole video into the model in a single shot.
#
# <center>
# <img src='https://drive.google.com/uc?export=download&id=1CbauSm5XTY7ypHYBHH7rDSnJ5LO9CUWX' width=400>
# </center>

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.1: Construct the Model</font>**
#
# To implement our LRCN architecture, we will use time-distributed **`Conv2D`** layers which will be followed by **`MaxPooling2D`** and **`Dropout`** layers. The feature extracted from the **`Conv2D`** layers will be then flattened using the  **`Flatten`** layer and will be fed to a **`LSTM`** layer. The **`Dense`** layer with softmax activation will then use the output from the **`LSTM`** layer to predict the action being performed.

# %%
def create_LRCN_model():
    '''
    This function will construct the required LRCN model.
    Returns:
        model: It is the required constructed LRCN model.
    '''

    # We will use a Sequential model for model construction.
    model = Sequential()
    
    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(TimeDistributed(Conv2D(16, (3, 3), padding='same',activation = 'relu'),
                              input_shape = (SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(TimeDistributed(MaxPooling2D((4, 4)))) 
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(32, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((4, 4))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    model.add(TimeDistributed(Dropout(0.25)))
    
    model.add(TimeDistributed(Conv2D(64, (3, 3), padding='same',activation = 'relu')))
    model.add(TimeDistributed(MaxPooling2D((2, 2))))
    #model.add(TimeDistributed(Dropout(0.25)))
                                      
    model.add(TimeDistributed(Flatten()))
                                      
    model.add(LSTM(32))
                                      
    model.add(Dense(len(CLASSES_LIST), activation = 'softmax'))

    ########################################################################################################################

    # Display the models summary.
    model.summary()
    
    # Return the constructed LRCN model.
    return model

# %% [markdown]
# Now we will utilize the function **`create_LRCN_model()`** created above to construct the required `LRCN` model.

# %%
# Construct the required LRCN model.
LRCN_model = create_LRCN_model()

# Display the success message.
print("Model Created Successfully!")
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed_6 (TimeDis  (None, 20, 64, 64, 16)   448
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 20, 16, 16, 16)   0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 20, 16, 16, 16)   0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 20, 16, 16, 32)   4640
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 20, 4, 4, 32)     0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 20, 4, 4, 32)     0
#  stributed)
#
#  time_distributed_12 (TimeDi  (None, 20, 4, 4, 64)     18496
#  stributed)
#
#  time_distributed_13 (TimeDi  (None, 20, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_14 (TimeDi  (None, 20, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_15 (TimeDi  (None, 20, 2, 2, 64)     36928
#  stributed)
#
#  time_distributed_16 (TimeDi  (None, 20, 1, 1, 64)     0
#  stributed)
#
#  time_distributed_17 (TimeDi  (None, 20, 64)           0
#  stributed)
#
#  lstm (LSTM)                 (None, 32)                12416
#
#  dense_2 (Dense)             (None, 14)                462
#
# =================================================================
# Total params: 73,390
# Trainable params: 73,390
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Check Model’s Structure:</font>**
#
# Now we will use the **`plot_model()`** function to check the structure of the constructed `LRCN` model. As we had checked for the previous model.

# %%
# Plot the structure of the contructed LRCN model.
plot_model(LRCN_model, to_file = 'LRCN_model_structure_plot.png', show_shapes = True, show_layer_names = True)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.2: Compile & Train the Model</font>**
#
#
# After checking the structure, we will compile and start training the model.

# %%
# Create an Instance of Early Stopping Callback.
early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 15, mode = 'min', restore_best_weights = True)
 
# Compile the model and specify loss function, optimizer and metrics to the model.
LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])

# Start training the model.
LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 1, batch_size = 4 ,
                                             shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
# Out:
# 65/65 [==============================] - 5s 58ms/step - loss: 2.6190 - accuracy: 0.1284 - val_loss: 2.6500 - val_accuracy: 0.0615

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Evaluating the trained Model</font>**
#
# As done for the previous one, we will evaluate the `LRCN` model on the test set.

# %%
# Evaluate the trained model.
model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
# Out:
# 4/4 [==============================] - 0s 67ms/step - loss: 2.6411 - accuracy: 0.1111

# %% [markdown]
# #### **<font style="color:rgb(134,19,348)">Save the Model</font>**
#
# After that, we will save the model for future uses using the same technique we had used for the previous model.

# %%
# Get the loss and accuracy from model_evaluation_history.
model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history

# Define the string date format.
# Get the current Date and Time in a DateTime Object.
# Convert the DateTime object to string according to the style mentioned in date_time_format string.
date_time_format = '%Y_%m_%d__%H_%M_%S'
current_date_time_dt = dt.datetime.now()
current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    
# Define a useful name for our model to make it easy for us while navigating through multiple saved models.
model_file_name = f'LRCN_model___Date_Time_{current_date_time_string}___Loss_{model_evaluation_loss}___Accuracy_{model_evaluation_accuracy}.h5'

# Save the Model.
LRCN_model.save(model_file_name)

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Step 5.3: Plot Model’s Loss & Accuracy Curves</font>**
#
# Now we will utilize the function **`plot_metric()`** we had created above to visualize the training and validation metrics of this model.

# %%
# Visualize the training and validation loss metrices.
plot_metric(LRCN_model_training_history, 'loss', 'val_loss', 'Total Loss vs Total Validation Loss')

# %%
# Visualize the training and validation accuracy metrices.
plot_metric(LRCN_model_training_history, 'accuracy', 'val_accuracy', 'Total Accuracy vs Total Validation Accuracy')

# %% [markdown]
# ## **<font style="color:rgb(134,19,348)">Step 6: Test the Best Performing Model on YouTube videos</font>**
#
# From the results, it seems that the LRCN model performed significantly well for a small number of classes. so in this step, we will put the `LRCN` model to test on some youtube videos.

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Create a Function to Download YouTube Videos:</font>**
#
# We will create a function **`download_youtube_videos()`** to download the YouTube videos first using **`pafy`** library. The library only requires a URL to a video to download it along with its associated metadata like the title of the video.

# %%
def download_youtube_videos(youtube_video_url, output_directory):
     '''
    This function downloads the youtube video whose URL is passed to it as an argument.
    Args:
        youtube_video_url: URL of the video that is required to be downloaded.
        output_directory:  The directory path to which the video needs to be stored after downloading.
    Returns:
        title: The title of the downloaded youtube video.
    '''
 
     # Create a video object which contains useful information about the video.
     video = pafy.new(youtube_video_url)
 
     # Retrieve the title of the video.
     title = video.title
 
     # Get the best available quality object for the video.
     video_best = video.getbest()
 
     # Construct the output file path.
     output_file_path = f'{output_directory}/{title}.mp4'
 
     # Download the youtube video at the best available quality and store it to the contructed path.
     video_best.download(filepath = output_file_path, quiet = True)
 
     # Return the video title.
     return title

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Download a Test Video:</font>**
#
# Now we will utilize the function **`download_youtube_videos()`** created above to download a youtube video on which the `LRCN` model will be tested.

# %%
# Make the Output directory if it does not exist
test_videos_directory = 'test_videos'
os.makedirs(test_videos_directory, exist_ok = True)

# Download a YouTube Video.
video_title = download_youtube_videos('https://www.youtube.com/watch?v=8u0qjmHIOcE', test_videos_directory)

# Get the YouTube Video's path we just downloaded.
input_video_file_path = f'{test_videos_directory}/{video_title}.mp4'

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Create a Function To Perform Action Recognition on Videos</font>**
#
# Next, we will create a function **`predict_on_video()`** that will simply read a video frame by frame from the path passed in as an argument and will perform action recognition on video and save the results.

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform action recognition on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    output_file_path: The path where the ouput video with the predicted action being performed overlayed will be stored.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Initialize the VideoWriter Object to store the output video in the disk.
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc('M', 'P', '4', 'V'), 
                                   video_reader.get(cv2.CAP_PROP_FPS), (original_video_width, original_video_height))

    # Declare a queue to store video frames.
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)

    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Iterate until the video is accessed successfully.
    while video_reader.isOpened():

        # Read the frame.
        ok, frame = video_reader.read() 
        
        # Check if frame is not read properly then break the loop.
        if not ok:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255

        # Appending the pre-processed frame into the frames list.
        frames_queue.append(normalized_frame)

        # Check if the number of frames in the queue are equal to the fixed sequence length.
        if len(frames_queue) == SEQUENCE_LENGTH:

            # Pass the normalized frames to the model and get the predicted probabilities.
            predicted_labels_probabilities = LRCN_model.predict(np.expand_dims(frames_queue, axis = 0))[0]

            # Get the index of class with highest probability.
            predicted_label = np.argmax(predicted_labels_probabilities)

            # Get the class name using the retrieved index.
            predicted_class_name = CLASSES_LIST[predicted_label]

        # Write predicted class name on top of the frame.
        cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Write The frame into the disk using the VideoWriter Object.
        video_writer.write(frame)
        
    # Release the VideoCapture and VideoWriter objects.
    video_reader.release()
    video_writer.release()

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Perform Action Recognition on the Test Video</font>**
#
# Now we will utilize the function **`predict_on_video()`** created above to perform action recognition on the test video we had downloaded using the function **`download_youtube_videos()`** and display the output video with the predicted action overlayed on it.

# %%
# Construct the output video path.
output_video_file_path = f'C:\\Users\\acer\\Downloads\\testing\\videarson-Output-SeqLen{SEQUENCE_LENGTH}.mp4'

# Perform Action Recognition on the Test Video.
predict_on_video(f'C:\\Users\\acer\\Downloads\\testing\\videarson.mp4', output_video_file_path, SEQUENCE_LENGTH)

# Display the output video.
VideoFileClip(output_video_file_path, audio=False, target_resolution=(300,300)).ipython_display()
# Out:
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# ...
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-c6d985fd2396> in <module>
#       6
#       7 # Display the output video.
# ----> 8 VideoFileClip(output_video_file_path, audio=False, target_resolution=(300,300)).ipython_display()
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218
#     219     return HTML2(html_embed(clip, filetype=filetype, maxduration=maxduration,
# --> 220                 center=center, rd_kwargs=rd_kwargs, **html_kwargs))
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\html_tools.py in html_embed(clip, filetype, maxduration, rd_kwargs, center, **html_kwargs)
#      96             kwargs.update(rd_kwargs)
#      97             clip.write_videofile(**kwargs)
# ---> 98         elif isinstance(clip,AudioClip):
#      99             filename = TEMP_PREFIX+".mp3"
#     100             kwargs = {'filename': filename, 'verbose':False}
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     133              for (arg, name) in zip(a, names)]
#     134     new_kw = {k: fun(v) if k=='fps' else v
# --> 135              for (k,v) in k.items()}
#     136
#     137     return f(clip, *new_a, **new_kw)
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# ~\anaconda3\lib\site-packages\moviepy\video\VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     298
#     299                         raise ValueError(
# --> 300                             "The audio_codec you chose is unknown by MoviePy. "
#     301                             "You should report this. In the meantime, you can "
#     302                             "specify a temp_audiofile with the right extension "
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     211                                 ffmpeg_params=ffmpeg_params) as writer:
#     212
# --> 213         nframes = int(clip.duration*fps)
#     214
#     215         for t,frame in clip.iter_frames(logger=logger, with_times=True,
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_writer.py in __init__(self, filename, size, fps, codec, audiofile, preset, bitrate, withmask, logfile, threads, ffmpeg_params)
#      86             '-i', '-', '-an',
#      87         ]
# ---> 88         if audiofile is not None:
#      89             cmd.extend([
#      90                 '-i', audiofile,
#
# TypeError: must be real number, not NoneType

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Create a Function To Perform a Single Prediction on Videos</font>**
#
#
# Now let's create a function that will perform a single prediction for the complete videos. We will extract evenly distributed **N** **`(SEQUENCE_LENGTH)`** frames from the entire video and pass them to the `LRCN` model. This approach is really useful when you are working with videos containing only one activity as it saves unnecessary computations and time in that scenario.

# %%
def predict_single_action(video_file_path, SEQUENCE_LENGTH):
    '''
    This function will perform single action recognition prediction on a video using the LRCN model.
    Args:
    video_file_path:  The path of the video stored in the disk on which the action recognition is to be performed.
    SEQUENCE_LENGTH:  The fixed number of frames of a video that can be passed to the model as one sequence.
    '''

    # Initialize the VideoCapture object to read from the video file.
    video_reader = cv2.VideoCapture(video_file_path)

    # Get the width and height of the video.
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Declare a list to store video frames we will extract.
    frames_list = []
    
    # Initialize a variable to store the predicted action being performed in the video.
    predicted_class_name = ''

    # Get the number of frames in the video.
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))

    # Calculate the interval after which frames will be added to the list.
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH),1)

    # Iterating the number of times equal to the fixed length of sequence.
    for frame_counter in range(SEQUENCE_LENGTH):

        # Set the current frame position of the video.
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)

        # Read a frame.
        success, frame = video_reader.read() 

        # Check if frame is not read properly then break the loop.
        if not success:
            break

        # Resize the Frame to fixed Dimensions.
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        
        # Normalize the resized frame by dividing it with 255 so that each pixel value then lies between 0 and 1.
        normalized_frame = resized_frame / 255
        
        # Appending the pre-processed frame into the frames list
        frames_list.append(normalized_frame)

    # Passing the  pre-processed frames to the model and get the predicted probabilities.
    predicted_labels_probabilities = LRCN_model.predict(np.expand_dims(frames_list, axis = 0))[0]

    # Get the index of class with highest probability.
    predicted_label = np.argmax(predicted_labels_probabilities)

    # Get the class name using the retrieved index.
    predicted_class_name = CLASSES_LIST[predicted_label]
    
    # Display the predicted action along with the prediction confidence.
    print(f'Action Predicted: {predicted_class_name}\nConfidence: {predicted_labels_probabilities[predicted_label]}')
        
    # Release the VideoCapture object. 
    video_reader.release()

# %% [markdown]
# ### **<font style="color:rgb(134,19,348)">Perform Single Prediction on a Test Video</font>**
#
# Now we will utilize the function **`predict_single_action()`** created above to perform a single prediction on a complete youtube test video that we will download using the function **`download_youtube_videos()`**, we had created above.

# %%
# Download the youtube video.
#video_title = download_youtube_videos('https://youtu.be/fc3w827kwyA', test_videos_directory)

# Construct tihe nput youtube video path
input_video_file_path = f'C:\\Users\\acer\\Downloads\\testing\\videarson.mp4'

# Perform Single Prediction on the Test Video.
predict_single_action(input_video_file_path, SEQUENCE_LENGTH)

# Display the input video.
clip=VideoFileClip(input_video_file_path, audio=False, target_resolution=(300,None))
ipython_display(clip,width=240)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Action Predicted: NormalVideos
# Confidence: 0.07687274366617203
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-8f43ea54bf5a> in <module>
#      10 # Display the input video.
#      11 clip=VideoFileClip(input_video_file_path, audio=False, target_resolution=(300,None))
# ---> 12 ipython_display(clip,width=240)
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218
#     219     return HTML2(html_embed(clip, filetype=filetype, maxduration=maxduration,
# --> 220                 center=center, rd_kwargs=rd_kwargs, **html_kwargs))
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\html_tools.py in html_embed(clip, filetype, maxduration, rd_kwargs, center, **html_kwargs)
#      96             kwargs.update(rd_kwargs)
#      97             clip.write_videofile(**kwargs)
# ---> 98         elif isinstance(clip,AudioClip):
#      99             filename = TEMP_PREFIX+".mp3"
#     100             kwargs = {'filename': filename, 'verbose':False}
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     133              for (arg, name) in zip(a, names)]
#     134     new_kw = {k: fun(v) if k=='fps' else v
# --> 135              for (k,v) in k.items()}
#     136
#     137     return f(clip, *new_a, **new_kw)
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     229     """
#     230     evaldict = dict(_call_=caller, _func_=func)
# --> 231     es = ''
#     232     for i, extra in enumerate(extras):
#     233         ex = '_e%d_' % i
#
# ~\anaconda3\lib\site-packages\moviepy\decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# ~\anaconda3\lib\site-packages\moviepy\video\VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     298
#     299                         raise ValueError(
# --> 300                             "The audio_codec you chose is unknown by MoviePy. "
#     301                             "You should report this. In the meantime, you can "
#     302                             "specify a temp_audiofile with the right extension "
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     211                                 ffmpeg_params=ffmpeg_params) as writer:
#     212
# --> 213         nframes = int(clip.duration*fps)
#     214
#     215         for t,frame in clip.iter_frames(logger=logger, with_times=True,
#
# ~\anaconda3\lib\site-packages\moviepy\video\io\ffmpeg_writer.py in __init__(self, filename, size, fps, codec, audiofile, preset, bitrate, withmask, logfile, threads, ffmpeg_params)
#      86             '-i', '-', '-an',
#      87         ]
# ---> 88         if audiofile is not None:
#      89             cmd.extend([
#      90                 '-i', audiofile,
#
# TypeError: must be real number, not NoneType

# %% [markdown]
# #  <center> <font style="color:rgb(234,19,148)">Join My Upcoming Computer Vision For Building Cutting Edge Applications Course</font>   </center>
#
# A Course that goes beyond basic applications and teaches you how to create some next-level apps that utilize physics, deep learning (LSTM + CNN) + classical image processing, hand and body gestures to do a variety of very interesting things.
# <center>
# <img src='https://drive.google.com/uc?export=download&id=1GYO8Rg6l1ClLmEtPQz7Mwve-aSt9vvId'></center>
#
# <br>
# <br>
#
# <center>  <a href="https://www.getdrip.com/forms/677961673/submissions/new"> <button>Join the Waitlist!</button>
# </a></center>
